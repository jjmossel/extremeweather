# %%
import sys
sys.path.append('..')

import numpy as np
import matplotlib.pyplot as plt
from utils.geodata import usa_gdf, usa_grid

# %%
usa_gdf().plot()
# Out:
# <AxesSubplot: >

# %%
x_mesh, y_mesh, mask_mesh = usa_grid(n_width=500,n_height=400)

# %%
z = x_mesh.copy()
z[~mask_mesh]=np.nan

plt.pcolor(x_mesh,y_mesh,z)
